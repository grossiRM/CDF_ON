# %%
import warnings;warnings.filterwarnings("ignore", category=UserWarning);import os; from pathlib import Path ;from PIL import Image ;from pix2tex.cli import LatexOCR    # ___ 10'' ___ 30''

# %%
File=Path(os.path.join(os.getcwd(),'_source','03.PNG')) ; img=Image.open(File) ;model=LatexOCR() ;print(model(img)) # https://doc.cfd.direct/notes/cfd-general-principles
# Out:
# \rho c_{p}\left({\frac{\partial T}{\partial t}}+\mathbf{u}\cdot\nabla T\right)=k\nabla^{2}T+{\dot{q}}

# %% [markdown]
# <font color='black'> **Continuity** <br>
# <font color='blue'>
# $
# \,\,\,\,\,\,\,      \nabla\cdot\mathbf{u}=0               \,\,\,\,\,\,\, [A]
# $ <br>
# <font color='black'> **Navier-Stokes** <br>
# <font color='green'>
# $
# \,\,\,\,\,\,\,      \rho\left({\frac{\partial\mathbf{u}}{\partial t}}+\mathbf{u}\cdot\nabla\mathbf{u}\right)=-\nabla p+\mu\nabla^{2}\mathbf{u}+{\boldsymbol{t}} \,\,\,\,\,\,\, [B]
# $ <br>
# <font color='black'> **Head Equation** <br>
# <font color='orange'>
# $
# \,\,\,\,\,\,\,      \rho c_{p}\left({\frac{\partial T}{\partial t}}+\mathbf{u}\cdot\nabla T\right)=k\nabla^{2}T+{\dot{q}}      \qquad [C]
# $

# %% [markdown]
# <font color='black'> **Example** <br>
# <font color='blue'>
# $
# \,\,\,\,\,\,\,      \nabla\cdot(\mathbf{uu})-\nabla\sigma=-\nabla
# $
# <font color='green'>
# $
# \,\,\,\,\,\,\,  \nabla\cdot\mathbf{u}=0      \,\,\,\,\,\,\,      [0.0]
# $
# <font color='orange'>
# $
# \,\,\,\,\,\,\,  \mathbf{\nabla}={\frac{\partial}{\partial x}}+{\frac{\partial}{\partial y}}+{\frac{\partial}{\partial z}}
# $

# %% [markdown]
# <font color='black'> **Fluid Dynamics** <br>
# <font color='blue'>
# $
# \,\,\,\,\,\,\,      t:=t+\Delta t
# $
# <font color='green'>
# $
# \;\;\;\;\;\;\       \int_{V}\Psi\,d V.      \,\,\,\,\,\,\,      [2.1]
# $
# <font color='orange'>
# $
# \;\;\;\;\;\;\
# \;\;\;\;\;\;\       \int_{S}\mathbf{n}\Psi\,d S
# \;\;\;\;\;\;\       \int_{S}(d\mathbf{S}\,\Psi),        \,\,\,\,\,\,\,      [2.2]
# $

# %% [markdown]
# <font color='black'> **2.1 Pressure ____________ ____________ ____________ ____________ ____________ ____________  2.2 Velocity** <br>
# <font color='blue'>
# $
# \,\,\,\,\,\,\,      d\mathbf{f}=(\mathbf{n}\,d S)\
# $
# <font color='green'>
# $
# p=d\mathbf{S}\,p     \,\,\,\,\,\,\,      [2.3]
# $
# <font color='red'>
# $
# \,\,\,\,\,\,\,
# \,\,\,\,\,\,\,      \mathrm{Pa}\equiv(\mathrm{kgm}^{-1}{\mathrm{s}}^{-2})    (\operatorname{m}^{2}{\mathrm{s}}^{-2})    {*\frac{1}{\rho}}
# $
# <font color='orange'>
# $
# \,\,\,\,\,\,\,      \,\,\,\,\,\,\,      \,\,\,\,\,\,\,
# \,\,\,\,\,\,\,       \mathbf{u}={\frac{d\mathbf{x}}{d t}}=\operatorname*{lim}_{\Delta t\to0}{\frac{\Delta\mathbf{x}}{\Delta t}}       \,\,\,\,\,\,\,      [2.4]
# $

# %% [markdown]
# <font color='black'> **2.3 Flow through a surface** <br>
# <font color='blue'>
# $
# \,\,\,\,\,\,\,       u_{n}=\mathbf{n}*\mathbf{u}.       \,\,\,\,\,\,\,      [2.5]
# $
# <font color='green'>
# $
# \,\,\,\,\,\,\,      d\phi=\mathbf{n}\cdot\mathbf{u}\,d S=d\mathbf{S}\cdot\mathbf{u}.        \,\,\,\,\,\,\,      [2.6]
# \,\,\,\,\,\,\,      \,\,\,\,\,\,\,  \,\,\,\,\,\,\,
# $
# <font color='orange'> **Flow through a surface** ____ [3.8]<
# <font color='orange'>
# $
# \,\,\,\,\,\,\,      \,\,\,\,\,\,\,
# \,\,\,\,\,\,\,      \phi_{\mathrm{f}}=\mathbf{S}_{\mathrm{f}}\cdot\mathbf{u}_{\mathrm{f}}
# $

# %% [markdown]
# #### <font color='red'> **Mass ___________________________________________________________________________** <br>
# <font color='red'> **2.4 Conservation of mass** <br>
# <font color='red'>
# $
# \,\,\,\,\,\,\,      {\frac{\partial\rho}{\partial t}}+\nabla\cdot\left(\rho\mathbf{u}\right)=0      \,\,\,\,\,\,\,      [2.8]
# $
# <font color='green'>
# $
# \,\,\,\,\,\,\,      \int_{V}\rho\,d V.
# $

# %% [markdown]
# <font color='red'> **Gauss** <br>
# <font color='red'>
# $
# \,\,\,\,\,\,\,\int_{S}(d\mathbf{S}\cdot\rho\mathbf{u})=\int_{V}\nabla\cdot(\rho\mathbf{u})\,d V.        \,\,\,\,\,\,\,      [2.9]
# $
# <font color='green'>
# $
# \,\,\,\,\,\,\,  \,\,\,\,\,\,\,  \,\,\,\,\,\,\,  \,\,\,\,\,\,\,
# \int_{V}\left[{\frac{\partial\rho}{\partial t}}+\nabla\cdot(\rho\mathbf{u})\right]\,d V=0        \,\,\,\,\,\,\,      [2.10]
# $

# %% [markdown]
# <font color='black'> **Divergence** <br>
# <font color='blue'>
# $
# \;\;\;\;\;\;\       \nabla*\mathbf{u}=\operatorname*{lim}_{\Delta V\to0}{\frac{1}{\Delta V}}\int_{S}(d\mathbf{S}*\mathbf{u})      \,\,\,\,\,\,\,      [2.11]
# $
# <font color='green'>
# $
# \,\,\,\,\,\,\,      \nabla\cdot\mathbf{u}={\frac{\partial u_{x}}{\partial x}}+{\frac{\partial u_{y}}{\partial y}}+{\frac{\partial u_{z}}{\partial z}}    \,\,\,\,\,\,\,      [2.13]
# \,\,\,\,\,\,\,      \mathbf{DIV stress [2.22]}
# $
# <font color='orange'>
# $
# \;\;\;\;\;\;\
# \,\,\,\,\,\,\,      \nabla*\sigma=\operatorname*{lim}_{\Delta V\to0}{\frac{1}{\Delta V}}\int_{S}(d S*\sigma)
# $

# %% [markdown]
# <font color='black'> **2.5 Time derivatives** <br>
# <font color='blue'>
# $
# {\frac{D\Psi}{D t}}={\frac{\partial\Psi}{\partial t}}+\mathbf{u}*\nabla\Psi      \,\,\,\,\,\,\,      [2.14]
# $
# <font color='green'>
# $
# \,\,\,\,\,\,\,
# \,\,\,\,\,\,\,
# \,\,\,\,\,\,\,
# \,\,\,\,\,\,\,      {\frac{D\Psi}{D t}}{\bigg|}_{x}={\frac{\partial\Psi}{\partial t}}{\bigg|}_{x}+{\frac{d x^{-u x}}{d t}}\,{\frac{\partial\Psi}{\partial x}}{\bigg|}_{t}
# \,\,\,\,\,\,\,      [2.15]
# $

# %% [markdown]
# <font color='black'> **2.6 Forces at a surface (Tractions & Tensions)** <br>
# <font color='blue'>
# $
# \,\,\,\,\,\,\,      df=t\Delta S      \,\,\,\,\,\,\,      [2.16]
# $
# <font color='green'>
# $
# \;\;\;\;\;\;\
# \mathbf{\sigma}={\left(\begin{array}{l}{\mathbf{t}_{x}}\\ {\mathbf{t}_{y}}\\ {\mathbf{t}_{z}}\end{array}\right)}=
# {\left(\begin{array}{l l l}     {\sigma_{x x}}&{\sigma_{x y}}&{\sigma_{x z}}
# \\                              {\sigma_{y x}}&{\sigma_{y y}}&{\sigma_{y z}}
# \\                              {\sigma_{z x}}&{\sigma_{z y}}&{\sigma_{z z}}\end{array}\right)}
# $
# <font color='orange'>
# $
# \;\;\;\;\;\;\       d\mathbf{f}=\mathbf{t}\,d S=(\mathbf{n}\cdot\sigma)\,d S=d\mathbf{S}\cdot\mathbf{\sigma}      \,\,\,\,\,\,\,      [2.17]
# $

# %% [markdown]
# #### <font color='red'> **2.7 Momentum ___________________________________________________________________________** <br>
# <font color='black'> **_** <br>
# <font color='blue'>
# $
# \,\,\,\,\,\,\,      \rho{\frac{D\mathbf{u}}{D t}}=\nabla\cdot\sigma+\rho\mathbf{b}      \,\,\,\,\,\,\,      [2.19]
# $
# <font color='green'>
# $
# \,\,\,\,\,\,\,      \int_{S}\mathbf{t}\,d S=\int_{S}\mathbf{n}\cdot\sigma\,d S=\int_{S}(d\mathbf{S}\cdot\sigma)=\int_{V}\nabla\cdot\sigma\,d V      \,\,\,\,\,\,\,      [2.20]
# $
# <font color='orange'>
# $
# \,\,\,\,\,\,\,      \int_{V}\left[\rho\frac{D\mathbf{u}}{D t}-\nabla*\sigma\ -\rho\mathbf{b}\right]\,d V=0      \,\,\,\,\,\,\,      [2.21]
# $
# <font color='blue'> ...[2.19] <br>

# %% [markdown]
# <font color='blue'> **2.8 Flow in a volume** <  <font color='black'> **.. & momentum** <
# <font color='blue'> **.. advecion**          <  <font color='black'> **.. material derivative for u** <  <br>
# <font color='blue'>
# $
# \,\,\,\,\,\,\,      \rho{\frac{D\mathbf{u}}{D t}}={\frac{\partial\rho\mathbf{u}}{\partial t}}+\nabla(\rho\mathbf{u}\mathbf{u})      \,\,\,\,\,\,\,      [2.26]
# \,\,\,\,\,\,\,      \,\,\,\,\,\,\,
# $
# <font color='green'>
# $
# \,\,\,\,\,\,\,      \rho{\frac{D\mathbf{u}}{D t}}=\rho{\frac{\partial\mathbf{u}}{\partial t}}+\rho\mathbf{u}\cdot\nabla\mathbf{u}
# \,\,\,\,\,\,\,      [*]$
# <font color='orange'>
# $
# \,\,\,\,\,\,\,      {\frac{\partial\rho\mathbf{u}}{\partial t}}-\mathbf{u}{\frac{\partial\rho}{\partial t}}\ +\nabla(\rho\mathbf{u}\mathbf{u})-\mathbf{u}\nabla\cdot(\rho\mathbf{u})
# $
# <font color='orange'>
# $
# \,\,\,\,\,\,\,
# \,\,\,\,\,\,\,      {\frac{\partial\rho\mathbf{u}}{\partial t}}+\nabla*(\rho\mathbf{u}\mathbf{u})=\nabla\cdot\sigma+\rho\mathbf{b}    \,\,\,\,\,\,\,      [2.27]
# $

# %% [markdown]
# <font color='blue'> **2.9 Conservation and boundedness** <br>
# <font color='blue'>
# $
# \,\,\,\,\,\,\,      \nabla\cdot\mathbf{u}=0  \,\,\,\,\,\,\, \mathbf{u}\cdot\nabla\Psi
# \,\,\,\,\,\,\,
# \,\,\,\,\,\,\,      \nabla\cdot(\mathbf{u}\Psi)=(\nabla\cdot\mathbf{u})\Psi+\mathbf{u}\cdot\nabla\Psi      \,\,\,\,\,\,\,      [2.31]
# \,\,\,\,\,\,\,      \,\,\,\,\,\,\,
# $
# <font color='green'>
# $
# \,\,\,\,\,\,\,
# \,\,\,\,\,\,\,      {\frac{\partial\Psi}{\partial t}}+u_{x}{\frac{\partial\Psi}{\partial x}}=0          \,\,\,\,\,\,\,      [2.32]
# $
# <font color='orange'>
# $
# \,\,\,\,\,\,\,      \Psi=f(x-u_{x}t)        \,\,= boundedness
# \,\,\,\,\,\,\,      (\mathbf{u}*\nabla\Psi)
# $

# %% [markdown]
# <font color='black'> **2.10 Fluid deformation** <br>
# <font color='blue'>
# $
# \,\,\,\,\,\,\,      \dot{\gamma}={\frac{\partial u_{x}}{\partial y}}
# $
# <font color='green'>
# $
# \,\,\,\,\,\,\,      \nabla\mathbf{u}={\left(\begin{array}{l l}  {0}   &{0}   \\{\dot{\gamma}}    &{0}   \end{array}\right)}
# \,\,\,\,\,\,\,      \mathbf{D}={\frac{1}{2}}\left(\begin{array}{c c}    {{0}}   &{{\dot{\gamma}}}  \\ {{\dot{\gamma}}} &{{0}}  \end{array}\right)
# \,\,\,\,\,\,\,      \mathbf{W}={\frac{1}{2}}\left(\begin{array}{c c}    {{0}}   &-{{\dot{\gamma}}}  \\ {{\dot{\gamma}}} &{{0}}  \end{array}\right)
# $
# <font color='orange'>
# $
# \,\,\,\,\,\,\,  \,\,\,\,\,\,\,  \,\,\,\,\,\,\,
# \mathbf{T}={\frac{1}{2}}(\mathbf{T}+\mathbf{T}^{\mathrm{T}})+{\frac{1}{2}}(\mathbf{T}-\mathbf{T}^{\mathrm{T}})={\mathrm{sym~}}\mathbf{T}+{\mathrm{skw~}}\mathbf{T}
# $

# %% [markdown]
# <font color='black'> **Rate of deformation tensor**
# <font color='blue'>
# $
# \,\,\,\,\,\,\,      \mathbf{D}={\mathrm{sym}}(\nabla\mathbf{u})  \,\,\,{\mathrm{and}} \,\,\,\mathbf{W}={\mathrm{skw}}(\nabla\mathbf{u})      \,\,\,\,\,\,\,      [2.33]
# $
# <font color='green'>
# $
# \,\,\,\,\,\,\,
# \,\,\,\,\,\,\,      \operatorname{tr}(\mathbf{T})=T_{x x}+T_{y y}+T_{z z}.      \,\,\,\,\,\,\,      [2.34]
# $
# <font color='orange'>
# $
# \,\,\,\,\,\,\,      \operatorname{tr}(\nabla\mathbf{u})={\frac{\partial u_{x}}{\partial x}}+{\frac{\partial u_{y}}{\partial y}}+{\frac{\partial u_{z}}{\partial z}}=\nabla\cdot\mathbf{u}              \,\,\,\,\,\,\,      [2.35]
# $

# %% [markdown]
# <font color='red'> **2.11 Vorticity** <br>
# <font color='blue'>
# $
# \,\,\,\,\,\,\,      {\boldsymbol{\omega}}=\nabla\times\mathbf{u}      \,\,\,\,\,\,\,      [2.37]
# $
# <font color='green'>
# $
# \,\,\,\,\,\,\,      \nabla\times\mathbf{u}=\left({\frac{\partial u_{z}}{\partial y}}-{\frac{\partial u_{y}}{\partial z}}(,)
#                                                  {\frac{\partial u_{x}}{\partial z}}-{\frac{\partial u_{z}}{\partial x}}(,)
#                                                  {\frac{\partial u_{y}}{\partial x}}-{\frac{\partial u_{x}}{\partial y}}\right)     \,\,\,\,\,\,\,      [2.38]
# $
# <font color='orange'>
# $
# \,\,\,\,\,\,\,      \overline{{{\int_{S}\left[d\mathbf{S}\cdot(\nabla\times u)\right]=\int_{S}(d\mathbf{S}\cdot\omega)=\int_{L}(d\mathbf{L}\cdot\mathbf{u})}}}     \,\,\,\,\,\,\,      [2.39]
# $

# %% [markdown]
# <font color='blue'> **2.12 Newtonian fluid model** <          <font color='green'> ------------- **(D)eformation rate**     <br>
# <font color='blue'>
# $
# \,\,\,\,\,\,\,      \mathbf{\tau}=2\mu\,\mathrm{dev}\,\mathbf{D}     \;\;\;\;    \mathbf{\sigma}=\mathbf{\tau}-p\mathbf{I}      \,\,\,\,\,\,\,  [2.41]
# $
# <font color='green'>
# $
# \,\,\,\,\,\,\,      \mathbf{\sigma}=f(\mathbf{D})-p\mathbf{I} \,\,\,\,\,\,\,      \operatorname{tr}(\mathbf{D})=\operatorname{tr}(\nabla\mathbf{u})=\nabla\cdot\mathbf{u}.     \,\,\,\,\,\,\,      ~ [2.35ii]
# $<font color='orange'>
# $
# \,\,\,\,\,\,\,      \nabla p=\operatorname*{lim}_{\Delta V\to0}{\frac{1}{\Delta V}}\int_{S}(d\mathbf{S}\,p)      \,\,\,\,\,\,\, [2.42]
# \,\,\,\,\,\,\,      \int_{S}(d S\Psi)=\int_{V}\nabla\Psi\,d V                                                    \,\,\,\,\,\,\, [2.43]
# $

# %% [markdown]
# <font color='black'> **2.13 Incompressible flow** <br>
# <font color='blue'>
# $
# \,\,\,\,\,\,\,      \mathbf{\sigma}=\mu\left[\nabla\mathbf{u}+\nabla\mathbf{u}^{\mathrm{{T}}}-{\frac{2}{3}}\mathbf{tr}(\nabla\mathbf{u})\mathbf{I}\right]-p\mathbf{I}   \,\,\,\,\,\,\,      [2.44 ]
# $
# <font color='green'>
# $
# \,\,\,\,\,\,\,      {\frac{\partial\rho\mathbf{u}}{\partial t}}+\nabla\cdot(\rho\mathbf{u}\mathbf{u}) - \nabla\cdot(\mu\nabla\mathbf{u})-\nabla\cdot\left[\mu(\nabla\mathbf{u})^{\mathrm{{T}}}\right]  + \frac{2}{3}\mu\nabla(\nabla\cdot\mathbf{u})=-\nabla p+\rho\mathbf{b}    \,\,\,\,\,\,\,      [2.45]
# $

# %% [markdown]
# <font color='red'> **2.11 Vorticity** <br>
# <font color='blue'>
# $
# \,\,\,\,\,\,\,      \nabla\cdot\mathbf{u} = 0      \,\,\,\,\,\,\,      [2.46]
# $
# <font color='green'>
# $
# \,\,\,\,\,\,\,      \,\,\,\,\,\,\,
# \,\,\,\,\,\,\,      {\frac{\partial\mathbf{u}}{\partial t}}+\nabla\cdot(\mathbf{u}\mathbf{u})-\nabla\cdot(\nu\nabla\mathbf{u})
#                     -(\nabla\nu)\cdot(\nabla\mathbf{u})=-\nabla p+\mathbf{b}        \,\,\,\,\,\,\,      [2.47]
# \,\,\,\,\,\,\,      \rho(\mathrm{cst})
# $
# <font color='orange'>
# $
# \,\,\,\,\,\,\,      \,\,\,\,\,\,\,      \,\,\,\,\,\,\,
# \,\,\,\,\,\,\,      \nabla^{2}p+\nabla\ ^{}[\nabla^{*}(\mathbf{uu})]=0.    \,\,\,\,\,\,      [2.47] Pressure!
# $

# %% [markdown]
# <font color='Black'> **2.14 Diffusion** <              <font color='blue'> **.. time derivative, advection, diffusion** <br>
# <font color='blue'>
# $
# \,\,\,\,\,\,        {\frac{\partial\mathbf{u}}{\partial t}} +\quad\nabla\cdot(\mathbf{uu})  -\quad\nabla\cdot(\nu\nabla\mathbf{u}) =\quad-\nabla p.\ \ \mathbf{}_{(2.49)}
# $
# <font color='green'>
# $
# \,\,\,\,\,\,\,      \,\,\,\,\,\,\,
# \,\,\,\,\,\,\,      \nabla*(\Gamma\nabla\Psi)=\operatorname*{lim}_{\Delta V\rightarrow0}\frac{1}{\Delta V}\int_{S}(d S\,\Gamma\nabla_{n}\Psi)     \,\,\,\,\,\,\,      [2.50]
# \,\,\,\,\,\,        \Gamma = \mathbf{diffusivity \,\,\,\ coefficient.}
# $

# %% [markdown]
# #### <font color='red'> **2.15 Energy ___________________________________________________________________________** <br>
# <font color='blue'> **2.15 Conservation of energy** <br>
# <font color='blue'>
# $
# \,\,\,\,\,\,        \rho{\frac{D e}{D t}}+\rho{\frac{D K}{D t}}=-\nabla\cdot\mathbf{q}+\rho r  +\nabla\cdot({\sigma}\cdot\mathbf{u})  +\rho\mathbf{b}\cdot\mathbf{u}       \,  [2.51]
# $
# <font color='green'>
# $
# \,\,\,\,\,\,\,  \int_{V}\rho\left[{\frac{D e}{D t}}+{\frac{D K}{D t}}\right]\,d V=
# \int_{S}\left[-d\mathbf{S}\cdot\mathbf{q}  +(d\mathbf{S}\cdot\mathbf{\sigma})\cdot\mathbf{u}\right]  +\int_{V}\left[\rho r+\rho\mathbf{b}\cdot\mathbf{u}\right]\,d V.       \,  [2.52]
# $
# <font color='orange'>
# $
# \,\,\,\,\,\,\,  \int_{V}\left[-\nabla\cdot\mathbf{q}+\nabla\cdot(\mathbf{\sigma}\cdot\mathbf{u})\right]\,d V.
# \,[2.53]
# $

# %% [markdown]
# <font color='black'> **2.16 Temperature** <br>
# <font color='blue'>
# $
# \,\,\,\,\,\,        \mathbf{q}=-\kappa\,\nabla T    \,\,\,\,\,\,\,  [2.54]
# \,\,\,\,\,\,\,  \nabla\cdot(\kappa\nabla T)
# $
# <font color='green'>
# $
# \,\,\,\,\,\,\,  \rho{\frac{D e}{D t}}=-\nabla\cdot\mathbf{q}+\rho r+\sigma\mathbf{:}\nabla\mathbf{u}    \,\,\,\,\,\,\,
# \,\,\,\,\,\,\,  [2.56]
# $
# <font color='orange'>
# $
# \,\,\,\,\,\,\,  \rho{\frac{D e}{D t}}=-\nabla\cdot\mathbf{q}+\rho r+\tau\mathbf{:}\nabla\mathbf{u}-p(\nabla\cdot\mathbf{u})   \,\,\,\,\,\,\,
# \,\,\,\,\,\,\,  [2.57]
# $

# %% [markdown]
# <font color='black'> **2.18 Heat capacity** <br>
# <font color='blue'>
# $
# \,\,\,\,\,\,        \rho{\frac{D e}{D t}}-\nabla\cdot\kappa\nabla T=0       \,\,\,\,\,\,\,  [2.60]
# $
# <font color='green'>
# $
# \,\,\,\,\,\,\,  c_{V}=\left({\frac{\partial e}{\partial T}}\right)_{V}       \,\,\,\,\,\,\,  [2.61]
# $
# <font color='grey'>
# $
# \,\,\,\,\,\,        \,\,\,\,\,\,        \,\,\,\,\,\,        \,\,\,\,\,\,        \,\,\,\,\,\,
# \,\,\,\,\,\,        \mathbf{\tau}:\nabla\mathbf{u}\equiv2\mu(\operatorname*{dev}\mathbf{D}) :\nabla\mathbf{u}\equiv2\mu(\operatorname*{dev}\mathbf{D}) : (\operatorname*{dev}\mathbf{D})
# \,\,\,\,\,\,\,  [2.58]
# $

# %% [markdown]
# <font color='black'> **2.19 Energy and temperature**
# <font color='blue'>
# $
# \,\,\,\,\,\,        e=\int_{T_{\mathrm{ref}}}^{T}c_{V}d T+e_{\mathrm{ref}}          \,\,\,\,\,\,\,  [2.62]
# $<font color='green'>
# $
# \,\,\,\,\,\,\,  \,\,\,\,\,\,\,
# \,\,\,\,\,\,\,  e=c_{V}(T-T_{\mathrm{ref}})+e_{\mathrm{ref}}            \,\,\,\,\,\,\,  [2.63]
# $<font color='orange'>
# $
# \,\,\,\,\,\,\,  \,\,\,\,\,\,\,
# \,\,\,\,\,\,\,  c v=\sum_{i=0}^{n}a_{i}T^{i}            \,\,\,\,\,\,\,  [2.64]
# $

# %% [markdown]
# <font color='black'> **2.20 Natural convection** < -----------
# <font color='blue'> **energy conservation** <---------------------------------------------------------------------
# <font color='red'> **momentum equation** <br>
# <font color='blue'>
# $
# \,\,\,\,\,\,        {\frac{\partial T}{\partial t}}+\nabla\cdot(\mathbf{u}T)-\nabla\cdot(\alpha\nabla T)=r          \,\,\,\,\,\,\,  [2.65]
# \,\,\,\,\,\,        \alpha=\kappa/\rho c V
# $<font color='green'>
# $
# \,\,\,\,\,\,\,  \,\,\,\,\,\,\,
# \,\,\,\,\,\,\,  \mathbf{b}={\frac{\rho(T,p)}{\rho_{0}}}\mathbf{g}   \,\,\, (Buoyancy)           \,\,\,\,\,\,\,  [2.66]
# $<font color='red'>
# $
# \,\,\,\,\,\,\,  \,\,\,\,\,\,\,
# {\frac{\partial\mathbf{u}}{\partial t}}+\nabla\cdot(\mathbf{uu})-\nabla\cdot(\nu\nabla\mathbf{u})=-\nabla p+{\frac{\rho(T,p)}{\rho_{0}}}\mathbf{g}      \,\,\,\,\,\,\,  [2.67]
# $

# %% [markdown]
# <font color='black'> **Scale similarity   --------------------** <
# <font color='red'> **momentum equation** <br>
# <font color='blue'>
# $
# \,\,\,\,\,\,\,      \mathrm{Sr}\,{\frac{\partial{\hat{\mathbf{u}}}}{\partial{\hat{t}}}}
#                     +{\hat{\nabla}}\cdot({\hat{\mathbf{u}}}{\hat{\mathbf{u}}})
#                     -\left({\frac{1}{\mathrm{Re}}}\right){\hat{\nabla}}^{2}{\hat{\mathbf{u}}}
#                     =   -\operatorname{Eu}{\hat{\nabla}}{\hat{p}}+\left({\frac{1}{\mathbb{Fr}^{2}}}\right)\mathbf{n}_{\mathbb{g  }}{\hat\rho}         \,\,\,\,\,\,\,  [2.68]
# $
# <font color='green'>
# $
# \,\,\,\,\,\,\,  \mathrm{Sr}=L/(\Gamma U) \, [Strouhal]
# $
# <font color='orange'>
# $
# \,\,\,\,\,\,\,  \mathrm{Re}=U L/\nu \, [Reynolds]
# $
# <font color='black'>
# $
# \,\,\,\,\,\,\,  \mathrm{Eu}=p_{0}/U^{2} \, [Euler]
# $
# <font color='orange'>
# $
# \,\,\,\,\,\,\,  \mathrm{Sr}=L/(T U) \, [Froude]
# $

# %% [markdown]
# <font color='black'> **2.21 Scale similarity**
# <font color='blue'>
# $
# \,\,\,\,\,\,\,      \mathrm{Sr}\,{\frac{\partial\hat{T}}{\partial\hat{t}}}+\hat{\nabla}     \cdot(\hat{\bf u}\hat{T})-\left({\frac{1}{\mathrm{Pe}}}\right)\hat{\nabla}^{2}\hat{T}=0,
# \,\,\,\,\,\,\,      [2.69]
# $
# <font color='green'>
# $
# \,\,\,\,\,\,\,
# \,\,\,\,\,\,\,
# \,\,\,\,\,\,\,
# \,\,\,\,\,\,\,  \mathrm{Pe}=U L/\alpha \ [Péclet \ number]
# $

# %% [markdown]
# #### <font color='red'> **Chapter 3 [Finite Colume] ____ Mesh ______ Discretisation _______ Asymmetric Z Matrix  (construction) _________________** <br>
# <font color='black'> **3.1 Finite volume mesh** <
# <font color='orange'> **-------------------------------------- Volume** <br>
# <font color='blue'>
# $
# \,\,\,\,\,\,\,      \mathbf{I}={\left(\begin{array}{l l l}{1}&{0}&{0}\\ {0}&{1}&{0}\\ {0}&{0}&{1}\end{array}\right)}
# $
# <font color='green'>
# $
# \,\,\,\,\,\,\,      \mathbf{C}_{i}={\frac{1}{|\mathbf{S}_{f}|}    }\sum^{N}  |{{\mathbf{s}}}_{t} |{\mathbf{C}}_{t}|
# $
# <font color='orange'>
# $
# \,\,\,\,\,\,\,      V=\int_{V}d V={\frac{1}{3}}\int_{V}\nabla\cdot\mathbf{x}\,d V={\frac{1}{3}}\int_{S}(d\mathbf{S}\cdot\mathbf{x})\approx{\frac{1}{3}}\sum_{f}\mathbf{S}_{f}\cdot\mathbf{C}_{f}
# $
# <font color='black'>
# $
# \,\,\,\,\,\,\,      \,\,\,\,\,\,\,
# \,\,\,\,\,\,\,      \int_{S}(d\mathbf{S}\cdot\Psi)\rightarrow\sum_{\mathbf{f}}\mathbf{S}_{\mathbf{f}}\cdot\Psi_{\mathbf{f}}
# $
# <font color='red'>
# $
# \,\,\,\,\,\,\,      \nabla(\mathbf{u}\Psi)\rightarrow{\frac{1}{V}}\sum_{\mathbf{f}}\phi_{\mathbf{f}}\Psi_{\mathbf{f}}
# $

# %% [markdown]
# <font color='black'> **DISCRETIZATION__Finite-volume_FVM**  <br> **cell centre**
# <font color='blue'>
# $
# \,\,\,\,\,\,\,      \mathbf{C}={\frac{1}{V}}\int_{V}\mathbf{x}\,d V={\frac{1}{2V}}\int_{V}\nabla|\mathbf{x}|^{2}\,d V
# ={\frac{1}{2V}}\int_{S}(d\mathbf{S}\,|\mathbf{x}|^{2})\approx{\frac{1}{2V}}\sum_{\mathbf{f}}\mathbf{S}_{\mathbf{f}}|\mathbf{C}_{\mathbf{f}}|
# $
# <font color='green'>
# $
# \,\,\,\,\,\,\,      \mathbf{S_{t}}=(\mathbf{p}_{i+1}-\mathbf{p}_{i})\times(\mathbf{a}-\mathbf{p}_{i})/2
# $
# <font color='orange'>
# $
# \,\,\,\,\,\,\,       \mathbf{C}_{\mathrm{t}}=(\mathbf{p}_{i+1}+\mathbf{p}_{i}+\mathbf{a})/3
# $

# %% [markdown]
# <font color='black'> **3.7 Laplacian discretisation** <br>
# <font color='indico'>
# $
# \,\,\,\,\,\,\,          \nabla*(\Gamma\nabla\Psi)=\operatorname*{lim}_{\Delta V\rightarrow0}\frac{1}{\Delta V}\int_{S}(d S\,\Gamma\nabla_{n}\Psi)
# \,\,\,\,\,\,\,          \rightarrow\frac{1}{V}\sum_{\mathrm{f}}|{\bf S}_{\mathrm{f}}|{\bf T}_{\mathrm{f}}\nabla_{\mathrm{n}}\Psi_{\mathrm{f}}           \,\,\,\,\,\,\, [3.2]
# $
# <font color='green'>
# $
# \,\,\,\,\,\,\,          \,\,\,\,\,\,\,
# \,\,\,\,\,\,\,          \Psi_{\mathrm{f}}=w\,\Psi_{\mathrm{P}}+(1-w)\,\Psi_{\mathrm{N}}        \,\,\,\,\,\,\, [3.3]
# $
# <font color='orange'>
# $
# \,\,\,\,\,\,\,      w={\frac{d_{\mathrm{fN}}}{d_{\mathrm{PN}}}}={\frac{\mathbf{n}*\!\mathbf{d}_{\mathrm{N}}}{\mathbf{n}*\!\left(\mathbf{d}_{\mathrm{P}}+\mathbf{d}_{\mathrm{N}}\right)}}
# \,\,\,\,\,\,\, [3.4]
# $

# %% [markdown]
# <font color='black'> **3.8 Surface normal gradient** <br>
# <font color='blue'>
# $
# \,\,\,\,\,\,\,      \nabla_{\mathbf{n}}\Psi_{\mathbf{f}}=C_{\Delta}(\Psi_{\mathbf{N}}-\Psi_{\mathbf{P}})               \,\,\,\,\,\,\, [3.5]
# \,\,\,\,\,\,\,      \,\,\,\,\,\,\,
# $
# <font color='green'> **Non-orthogonal correction** <
# <font color='green'>
# $
# \,\,\,\,\,\,\,      C_{\Delta}^{\mathrm{corr}}={\frac{1}{{\bf n}^{*}\Delta{\bf d}}}={\frac{1}{|\Delta{\bf d}|\cos\theta_{\bf n o}}}              \,\,\,\,\,\,\, [3.6]
# $
# <font color='orange'>
# $
# \,\,\,\,\,\,\,      \nabla_{\mathbf{n}}\Psi_{\mathbf{f}}=C_{\Delta}^{\mathrm{{corr}}}(\Psi_{\mathbf{N}}-\Psi_{\mathbf{P}})+(\mathbf{n}-C_{\Delta}^{\mathrm{{corr}}}\Delta\mathbf{d})*(\nabla\Psi)_{\mathbf{f}}.       \,\,\,\,\,\,\,       [3.7]
# $

# %% [markdown]
# <font color='black'> **3.9 Advection discretisation** <br>
# <font color='blue'>
# $
# \,\,\,\,\,\,\,      \int_{S}(d\mathbf{S}\cdot\Psi)\rightarrow\sum_{\mathbf{f}}\mathbf{S}_{\mathbf{f}}\cdot\Psi_{\mathbf{f}}
# $
# <font color='green'>
# $
# \,\,\,\,\,\,\,      \nabla*(\mathbf{u}\Psi)\to{\frac{1}{V}}\sum_{i}\phi_{i}\Psi_{i}
# $
# <font color='indico'>
# $
# \,\,\,\,\,\,\,  \nabla\cdot(\mathbf{u}\Psi)=\operatorname*{lim}_{\Delta V\to0}{\frac{1}{\Delta V}}\int_{S}(d\mathbf{S}\cdot\mathbf{u}\Psi)
# \,\,\,\,\,\,\,  \rightarrow\frac{1}{V}\sum_{i}\mathbf{S}_{i}\cdot\mathbf{u}_{i}\mathbf{\hat{w}}_{i}\rightarrow\frac{1}{V}\sum_{i}\phi_{i}\mathbf{\hat{w}}_{i}     \,\,\, [3.8]
# \,\,\,\,\,\,\,
# $
# <font color='indico'> **for a point** <

# %% [markdown]
# <font color='black'> **3.10 Upwind scheme** <br>
# <font color='blue'>
# $
# \,\,\,\,\,\,\,      {\frac{\partial\Psi}{\partial t}}+u_{x}{\frac{\partial\Psi}{\partial x}}=0          \,\,\,\,\,\,\,      [2.32]
# \,\,\,\,\,\,\,      \,\,\,\,\,\,\,
# $
# <font color='green'> **Taylor’s series** <
# <font color='green'>
# $
# \,\,\,\,\,\,\,      \Psi(x+\Delta x)=\Psi(x)+{\frac{\partial\Psi}{\partial x}}\Delta x+{\frac{\partial^{2}\Psi}{\partial x^{2}}}{\frac{\Delta x^{2}}{2}}+...              \,\,\,\,\,\,\, [3.9]
# \,\,\,\,\,\,\,      \,\,\,\,\,\,\,
# $
# <font color='orange'>
# $
# \,\,\,\,\,\,\,      {\frac{\Psi_{\mathrm{P}}-\Psi_{\mathrm{U}}}{\Delta x}}={\frac{\partial\Psi}{\partial x}}+{\frac{\partial^{2}\Psi}{\partial x^{2}}}{\frac{\Delta x}{2}}+\dots      \qquad [3.10]
# $

# %% [markdown]
# <font color='black'> **3.11 Limited advection schemes**
# <font color='blue'>
# $
# \,\,\,\,\,\,\,      \Psi_{\mathrm{f}}=(1-\beta)\Psi_{\mathrm{U}}+\beta\Psi_{\mathrm{L}}         \,\,\,\,\,\,\, [3.11]
# $
# <font color='green'>
# $
# \,\,\,\,\,\,\,      \,\,\,\,\,\,\,      \,\,\,\,\,\,\,
# \,\,\,\,\,\,\,      r=\operatorname*{max}\left[2{\frac{\Delta\mathrm{{a}}\cdot\nabla\Psi}    {|\Delta\mathrm{{d}}    |\nabla_{\mathrm{{n}}}\Psi_{\mathrm{{f}}}}}-1,0\right]\quad{\mathrm{for~scalar~}}\Psi.              \,\,\,\,\,\,\, [3.12]
# $

# %% [markdown]
# <font color='black'> **3.13 Limiting multiple components**
# <font color='blue'>
# $
# \,\,\,\,\,\,\,      r=2{\frac{\nabla_{\mathbf{n}}\Psi_{\mathbf{f}}\cdot\Delta\mathbf{a}\cdot\nabla\Psi}{|\Delta\mathbf{d}|\nabla_{\mathbf{n}}\Psi_{\mathbf{f}}\cdot\nabla_{\mathbf{n}}\Psi_{\mathbf{f}}}}-1,\quad{\mathrm{for~vector}}\,\Psi            \,\,\,\,\,\,\, [3.17]
# $

# %% [markdown]
# <font color='black'> **3.15 Gradient discretisation** <br>
# <font color='blue'>
# $
# \,\,\,\,\,\,\,      \nabla\Psi=\operatorname*{lim}_{\Delta V\to0}{\frac{1}{\Delta V}}\int_{S}(d S\Psi)\to{\frac{1}{V}}\sum_{\mathrm{f}}\mathbf{S}_{\mathrm{f}}\Psi_{\mathrm{f}}
# \,\,\,\,\,\,\, [3.18]
# $
# <font color='green'>
# $
# \,\,\,\,\,\,\,      \mathrm{G}=\sum_{i}w_{i a}^{2}\Delta\,\mathrm{d}\Delta\,\mathrm{d}              \,\,\,\,\,\,\, [3.19]
# $
# <font color='orange'>
# $
# \,\,\,\,\,\,\,      \nabla\Psi\to\frac{1}{V}\sum_{i}w_{i\mathrm{d}}^{2}G^{-1}\cdot\Delta\mathrm{d}\left(\Psi_{\mathrm{N}}-\Psi_{\mathrm{P}}\right)      \qquad [3.20]
# $

# %% [markdown]
# <font color='black'> **3.17 Time discretisation** <br>
# <font color='blue'>
# $
# \,\,\,\,\,\,\,      {\frac{\partial\Psi}{\partial t}}\rightarrow{\frac{\Psi-\Psi^{\circ}}{\Delta t}}     \,\,\,\,\,\,\, [3.21]
# $
# <font color='green'>
# $
# \,\,\,\,\,\,\,      \mathrm{C}0={\frac{u_{x}\Delta t}{\Delta x}}
# \,\,\,\,\,\,\,
# $
# <font color='green'> **[3.22] Courant number**
# <font color='orange'>
# $
# \,\,\,\,\,\,\,
# \,\,\,\,\,\,\,      \Psi=\Psi^{0}-\frac{\Delta t}{V}\sum_{f}\phi^{+}\Psi^{0} -\frac{\Delta t}{V}\sum_{f}\phi^{-}\Psi_{\mathrm{N}}^{0}=0  \,\,\,\,\,\,\,  [3.23]
# $
# <font color='black'>
# $
# \,\,\,\,\,\,\,
# \,\,\,\,\,\,\,      \mathrm{Co}={\frac{\Delta t}{V}}\sum_{\mathrm{f}}\phi^{+}  \,\,\,\,\,\,\,  [3.24]
# $

# %% [markdown]
# <font color='black'> **3.18 Second order time schemes** <br>
# <font color='blue'>
# $
# \,\,\,\,\,\,\,      {\frac{\Psi-\Psi^{o}}{\Delta t}}={\frac{\partial\Psi}{\partial t}}-{\frac{\partial^{2}\Psi}{\partial t^{2}}}{\frac{\Delta t}{2}}+O(\Delta t^{2})\dots
# \,\,\,\,\,\,\, [3.25]
# $
# <font color='green'>
# $
# \,\,\,\,\,\,\,      \frac{\partial^{2}\Psi}{\partial t^{2}}=\frac{\Psi-2\Psi^{o}+\Psi^{o o}}{\Delta t^{2}}+O(\Delta t^{2})\dots              \,\,\,\,\,\,\, [3.26]
# $
# <font color='orange'>
# $
# \,\,\,\,\,\,\,      {\frac{\partial\Psi}{\partial t}}\rightarrow{\frac{3\Psi-4\Psi^{\mathrm{e}}+\Psi^{\mathrm{oo}}}{2\Delta t}}      \,\,\,\,\,\,\, [3.27]
# $

# %% [markdown]
# <font color='black'> **3.19 Calculated derivatives** <br>
# <font color='blue'>
# $
# \,\,\,\,\,\,\,      {\frac{\partial\Psi}{\partial t}}\Big|_{\mathrm{Euler}}+{\frac{1}{2}}[\mathbf{A}\,|\mathbf{b}]\Psi+{\frac{1}{2}}\,[\mathbf{A}\,|\mathbf{b}]^{\circ}\Psi^{\circ}=0,
# \,\,\,\,\,\,\, [3.28]
# $
# <font color='green'>
# $
# \,\,\,\,\,\,\,      {\frac{\partial\Psi}{\partial t}}\rightarrow(1+\lambda){\frac{\Psi-\Psi^{o}}{\Delta t}}+\lambda\,[\,\mathbf{A}\,|\,\mathbf{b}]^{o}\,\Psi^{o}
# \,\,\,\,\,\,\, [3.29]
# $

# %% [markdown]
# #### <font color='red'> **Chapter 6 Turbulence _________________ _________________ _________________ _________________ _________________** <br>
# <font color='black'> **REF** <br>
# <font color='blue'>
# $
# \,\,\,\,\,\,\,      I \ would               \,\,\,\,\,\,\, [9.9]
# $
# <font color='green'>
# $
# \,\,\,\,\,\,\,      I \ should              \,\,\,\,\,\,\, [9.8]
# $
# <font color='orange'>
# $
# \,\,\,\,\,\,\,      \mathbf {I \ Must}      \qquad [9.7]
# $

# %% [markdown]
# #### <font color='red'> **Chapter 6 Turbulence _________________ _________________ _________________ _________________ _________________** <br>
# <font color='black'> **REF** <br>
# <font color='blue'>
# $
# \,\,\,\,\,\,\,      I \ would               \,\,\,\,\,\,\, [9.9]
# $
# <font color='green'>
# $
# \,\,\,\,\,\,\,      I \ should              \,\,\,\,\,\,\, [9.8]
# $
# <font color='orange'>
# $
# \,\,\,\,\,\,\,      \mathbf {I \ Must}      \qquad [9.7]
# $

# %%
File=Path(os.path.join(os.getcwd(),'_source','01.PNG')) ; img=Image.open(File) ;model=LatexOCR() ;print(model(img))
# Out:
# {\frac{\partial v_{i}}{\partial t}}+v_{j}{\frac{\partial v_{i}}{\partial x_{j}}}=-{\frac{1}{\rho}}{\frac{\partial p}{\partial x_{i}}}+{\frac{1}{3}}\nu{\frac{\partial}{\partial x_{i}}}\big({\frac{\partial v_{j}}{\partial x_{j}}}\big)+\nu{\frac{\partial^{2}v_{i}}{\partial x_{j}\partial x_{j}}}+f_{i}{\frac{\partial v_{i}}{\partial x_{j}}}+f_{i}{\frac{\partial v_{i}}{\partial t_{j}}}+f_{i}{\frac{\partial v_{i}}{\partial x_{j}}}+f_{i}{\frac{\partial v_{i}}{\partial t_{j}}}+f_{i}{\frac{\partial v_{i}}{\partial x_{j}}}+f_{i}{\frac{\partial v_{i}}{\partial x_{j}}}}

# %% [markdown]
# #### <font color='red'> **Chapter 6 Turbulence _________________ _________________ _________________ _________________ _________________** <br>
# <font color='black'> **REF** <br>
# <font color='blue'>
# $
# \,\,\,\,\,\,\,      I \ would               \,\,\,\,\,\,\, [9.9]
# $
# <font color='green'>
# $
# \,\,\,\,\,\,\,      I \ should              \,\,\,\,\,\,\, [9.8]
# $
# <font color='orange'>
# $
# \,\,\,\,\,\,\,      \mathbf {I \ Must}      \qquad [9.7]
# $

# %% [markdown]
# #### <font color='black'> **Imcompressible Navier-Stouks _________________ _________________ _________________ _________________ _________________**
# <font color='blue'> **aaaaa**
# <font color='blue'>
# $$
# \,\,\,\,\,\,\,      \frac{\partial v_{i}}{\partial t}   +v_{j}{\frac{\partial v_{i}}{\partial x_{j}}}   =-{\frac{1}{\rho}}{\frac{\partial p}{\partial x_{i}}}
# +{\frac{1}{3}}\nu{\frac{\partial}{\partial x_{i}}}\big({\frac{\partial v_{j}}{\partial x_{j}}}\big)     +\nu{\frac{\partial^{2}v_{i}}{\partial x_{j}\partial x_{j}}}    +f_{i}
# \,\,\,\,\,\,\, [1.1]
# $$
# <font color='red'> **bbbbb**
# <font color='red'>
# $$
# \,\,\,\,\,\,\,      \frac{\partial v_{i}}{\partial t}   +v_{j}{\frac{\partial v_{i}}{\partial x_{j}}}   =-{\frac{1}{\rho}}{\frac{\partial p}{\partial x_{i}}}
# +{\frac{1}{3}}\nu{\frac{\partial}{\partial x_{i}}}\big({\frac{\partial v_{j}}{\partial x_{j}}}\big)     +\nu{\frac{\partial^{2}v_{i}}{\partial x_{j}\partial x_{j}}}    +f_{i}
# \,\,\,\,\,\,\, [1.2]
# \,\,\,\,\,\,\,      \,\,\,\,\,\,\,      \,\,\,\,\,\,\,      \,\,\,\,\,\,\,
# \,\,\,\,\,\,\,      \frac{\partial v_{i}}{\partial t}   +v_{j}{\frac{\partial v_{i}}{\partial x_{j}}}   =-{\frac{1}{\rho}}{\frac{\partial p}{\partial x_{i}}}
# +{\frac{1}{3}}\nu{\frac{\partial}{\partial x_{i}}}\big({\frac{\partial v_{j}}{\partial x_{j}}}\big)     +\nu{\frac{\partial^{2}v_{i}}{\partial x_{j}\partial x_{j}}}    +f_{i}
# \,\,\,\,\,\,\, [1.3]
# $$

# %% [markdown]
# #### <font color='red'> **Chapter 6 Turbulence _________________ _________________ _________________ _________________ _________________** <br>
# <font color='black'> **REF** <br>
# <font color='blue'>
# $
# \,\,\,\,\,\,\,      \nabla\cdot\mathbf{u}=0               \,\,\,\,\,\,\, [9.9]
# $
# <font color='green'>
# $
# \,\,\,\,\,\,\,      I \ should              \,\,\,\,\,\,\, [9.8]
# $
# <font color='orange'>
# $
# \,\,\,\,\,\,\,      \mathbf {I \ Must}      \qquad [9.7]
# $
