# %% [markdown]
# <font color='black'> **24.4.4 examples.convection.exponential1DSource** </font>
# <font color='orange'> **___SOURCE** </font> <br>
# $ python examples/convection/exponential1D/mesh1D.py    _______ & tri2d

# %% [markdown]
# <font color='black'> **24.4.5 examples.convection.exponential2D** </font>  <br>
# $ python examples/convection/exponential2D/mesh2D.py	_______ & tri2D.py

# %% [markdown]
# <font color='black'> **24.4.6 examples.convection.peclet** </font>  <br>
# $ python examples/convection/peclet.py  _______ & source.py

# %% [markdown]
# <font color='black'> **24.4.7 examples.convection.powerLaw1D** </font>  <br>
# $ python examples/convection/powerLaw1D/mesh1D.py

# %% [markdown]
# <font color='black'> **24.4.8 examples.convection.robin** </font>  ____
# <font color='red'> **Robin boundary condition** </font>  <br>
# $ python examples/convection/robin.py

# %% [markdown]
# <font color='black'> **24.7 examples.flow** </font>  ____
# <font color='red'> **24.7.1 examples.flow.stokesCavity** </font>  <br>
# $ python examples/flow/stokesCavity.py

# %% [markdown]
# <font color='black'> **24.8 examples.levelSet** </font>  <br>
# >><font color='red'> **24.8.1 examples.levelSet.advection** </font>  <br>
# >><font color='red'> **24.8.2 examples.levelSet.distanceFunction	cicle, interior, mesh1D, square, (test)** </font>  <br>
# >><font color='red'> **24.8.3 examples.levelSet.electroChem** </font>  <br>
# >><font color='red'> **24.8.4 examples.levelSet.surfactant** </font>  <br>
# <font color='blue'> $ python examples/flow/stokesCavity.py </font>  <br>

# %% [markdown]
# <font color='black'> **24.9 examples.meshing** </font>  <br>
# >><font color='red'> **24.9.1** </font>  <br>
# >><font color='red'> **24.9.2** </font>  <br>
# >><font color='red'> **24.9.3** </font>  <br>

# %% [markdown]
# <font color='black'> **24.10 examples.parallel** </font>  <br>
# <font color='black'> **24.11 examples.phase** </font>  <br>
# <font color='black'> **24.12 examples.reactiveWetting** </font>  <br>
# <font color='black'> **24.13 examples.riemann** </font>  <br>
# <font color='black'> **24.13.1 examples.riemann.acoustics** </font>  <br>
