# %% [markdown]
# # Stokes Cavity with an Ostwald fluid

# %% [markdown]
# #### In this notebook the Stokes cavity example is re-worked to incorporate a time independent non-Newtonian fluid model. <br>
# For the Stokes cavity equation with a Newtonian fluid we used the following governing equations: <br>
# https://github.com/usnistgov/fipy/blob/master/examples/flow/stokesNonNewtonian.ipynb

# %% [markdown]
# <font color='black'> **REF** <br>
# <font color='blue'>
# $
# \,\,\,\,\,\,\,      \nabla\cdot(\mu\nabla\mathbf{u})= \nabla p
# $
# <font color='green'>
# $
# \,\,\,\,\,\,\,      \nabla\cdot\mathbf{u}= 0
# $
# <font color='orange'>
# $
# \,\,\,\,\,\,\,      \nabla\cdot\tau=\nabla p
# $
# <font color='blue'>
# $
# \,\,\,\,\,\,\,      \tau=\mu(\dot{\gamma})\dot{\gamma}
# $
# <font color='red'>
# $
# \,\,\,\,\,\,\,      \mu({\dot{\gamma}})=C|{\dot{\gamma}}|^{m-1}
# $
# <font color='blue'>
# $
# \,\,\,\,\,\,\,      \nabla\cdot(C|\cdot\rangle\vert^{m-1}\dot{\gamma})=\nabla p
# $

# %% [markdown]
# <font color='black'> **REF** <br>
# <font color='blue'>
# $
# \dot{\gamma} =
# \begin{array} {c c}
#     {{{2\frac{\partial u}{\partial x}}} }
# &   {{\left(\frac{\partial u}{\partial y}+\frac{\partial v}{\partial x}\right)}}
# \\  {{\left(\frac{\partial u}{\partial y}+\frac{\partial v}{\partial x}\right)}}
# &   {{2\frac{\partial v}{\partial y}}}
# \end{array}
# $

# %%
import numpy as np

from fipy import (Grid2D, CellVariable, FaceVariable, DiffusionTerm, Viewer,numerix)

# %%
L = 1.0 # Cavity dimensions
N = 50 # Number of divisions
dL = L / N # Cell sizes
viscosity = 1. # Consistency viscosity value. The value "C" from Ostwald fluid model.
m = 1.5 # First value of the behavior constant will set the case as Newtonian
eps = 0.025 # criteria to stop
U = 1.0 # upper boundary fluid velocity
#   0.4 for pressure and 0.02 for velocity worked fine for 0.5<=m<=1.5
#   worked for m=0.25
pressureRelaxation = 0.4
velocityRelaxation = 0.02 
Re = U ** (2 - m) * L ** m / viscosity # Added non-Newtonian Reynolds number calculation for reference
# the number of sweeps when explicit called is 300, when running as a test is 5
sweeps = 15000

# %% [markdown]
# We then build the mesh using a 2D grid.

# %%
mesh = Grid2D(nx=N, ny=N, dx=dL, dy=dL)

# %% [markdown]
# Then, we create the variables which keep the solution value and initialize it with null values. In this case we need variables for pressure, pressure correction, and two directions of the velocity field.

# %%
pressure = CellVariable(mesh=mesh, name='pressure')
pressureCorrection = CellVariable(mesh=mesh)
xVelocity = CellVariable(mesh=mesh, name='X velocity')
yVelocity = CellVariable(mesh=mesh, name='Y velocity')

# %% [markdown]
# For coupling purposes the velocity is also declared as a face variable. It will be used to apply the [SIMPLE](https://en.wikipedia.org/wiki/SIMPLE_algorithm) calculation for pressure correction.

# %%
velocity = FaceVariable(mesh=mesh, rank=1)

# %% [markdown]
# Compute the shear strain, which is used in the velocity equation.

# %%
velocity_variable = CellVariable(mesh=mesh, name='vel_var',rank=1)

# need this to get through the first step without error
velocity_variable[:] = 1e-6 * np.random.random(velocity_variable.shape)

# %%
def trans2x2(var):
    # Transpose for  2 x 2 variable
    return [[1, 0], [0, 1]] * var + [[0, 1], [0, 0]] * var[1, 0] + [[0, 0], [1, 0]] * var[0, 1]

def mag2x2(var):
    # Magnitude for 2 x 2 variable
    return numerix.sqrt((var**2).sum(0).sum(0))

# %%
shear_strain = 0.5 * (velocity_variable.grad + trans2x2(velocity_variable.grad))

# %%
def xterm(mat):
    return viscosity * np.array(mat) * mag2x2(shear_strain) ** (m-1)

xTerm1 = xterm([[1, 0], [0, 1 / 2]])
xTerm2 = xterm([[0, 1 / 2], [0, 0]])
yTerm1 = xterm([[0, 0], [0, 1 / 2]])
yTerm2 = xterm([[1 / 2, 0], [0, 1]])

# %%
xVelocityEq = DiffusionTerm(xTerm1,var=xVelocity)+DiffusionTerm(xTerm2,var=yVelocity)-pressure.grad.dot([1., 0.])
yVelocityEq = DiffusionTerm(yTerm1,var=xVelocity)+DiffusionTerm(yTerm2,var=yVelocity)-pressure.grad.dot([0., 1.])

# %% [markdown]
# We need the pressure correction equation.

# %%
ap = CellVariable(mesh=mesh, value=1.)
coeff = 1. / ap.arithmeticFaceValue * mesh._faceAreas * mesh._cellDistances
pressureCorrectionEq = DiffusionTerm(coeff=coeff) - velocity.divergence

# %% [markdown]
# This method also incorporates the Rhie-Chow interpolation correction to soften the numerical oscillations. For the SIMPLE method we linearize the equation and use the linear coefficients, and we can use the same approach, even though we now have a non-Newtonian fluid.

# %%
from fipy.variables.faceGradVariable import _FaceGradVariable
volume = CellVariable(mesh=mesh, value=mesh.cellVolumes, name='Volume')
contrvolume = volume.arithmeticFaceValue

# %% [markdown]
# Set the boundary conditions to no slip and uniform velocity in the upper boundary.

# %%
xVelocity.constrain(0., mesh.facesRight | mesh.facesLeft | mesh.facesBottom)
xVelocity.constrain(U, mesh.facesTop)
yVelocity.constrain(0., mesh.exteriorFaces)
X, Y = mesh.faceCenters
pressureCorrection.constrain(0., mesh.facesLeft & (Y < dL))

# %% [markdown]
# Set up the viewers

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (10,10)

# %%
if __name__ == '__main__':
    try:
        from fipy.viewers.matplotlibViewer import MatplotlibStreamViewer
        viewer = MatplotlibStreamViewer(vars=(velocity),
                   xmin=0., xmax=1., ymin=0., ymax=1.)
    except:
        viewer = Viewer(vars=(velocity),
                   xmin=0., xmax=1., ymin=0., ymax=1., scale=5)

# %% [markdown]
# Now solve the problem with sweep instead of solve.

# %%
for sweep in range(sweeps):
# while min(xres,yres) > 0.01:
    
     ## solve the Stokes equations to get starred values
     xVelocityEq.cacheMatrix()
     
     # solving for x and y velocities
     
     xres = xVelocityEq.sweep(var=xVelocity,
                              underRelaxation=velocityRelaxation)
  
     xmat = xVelocityEq.matrix

     yres = yVelocityEq.sweep(var=yVelocity,
                              underRelaxation=velocityRelaxation)

     # solving again to adjust the x and y velocity values ########################
     xres = xVelocityEq.sweep(var=xVelocity,
                              underRelaxation=velocityRelaxation)
     xmat = xVelocityEq.matrix

     yres = yVelocityEq.sweep(var=yVelocity,
                              underRelaxation=velocityRelaxation)
     ############################################################################
     
    
     ## update the ap coefficient from the matrix diagonal
     ap[:] = -numerix.asarray(xmat.takeDiagonal())

     ## update the face velocities based on starred values with the
     ## Rhie-Chow correction.
     ## cell pressure gradient
     presgrad = pressure.grad
     ## face pressure gradient
     facepresgrad = _FaceGradVariable(pressure)

     velocity[0] = xVelocity.arithmeticFaceValue \
          + contrvolume / ap.arithmeticFaceValue \
          * (presgrad[0].arithmeticFaceValue-facepresgrad[0])
     velocity[1] = yVelocity.arithmeticFaceValue \
          + contrvolume / ap.arithmeticFaceValue \
          * (presgrad[1].arithmeticFaceValue-facepresgrad[1])
     velocity[..., mesh.exteriorFaces.value] = 0.
     velocity[0, mesh.facesTop.value] = U

     ## solve the pressure correction equation
     pressureCorrectionEq.cacheRHSvector()
     ## left bottom point must remain at pressure 0, so no correction
     pres = pressureCorrectionEq.sweep(var=pressureCorrection)
     rhs = pressureCorrectionEq.RHSvector

     ## update the pressure using the corrected value
     pressure.setValue(pressure + pressureRelaxation * pressureCorrection )
     ## update the velocity using the corrected pressure
     xVelocity.setValue(xVelocity - pressureCorrection.grad[0] \
                                  / ap * mesh.cellVolumes)
     yVelocity.setValue(yVelocity - pressureCorrection.grad[1] \
                                  / ap * mesh.cellVolumes)
     
     velocity_variable.setValue([xVelocity,yVelocity])

     if __name__ == '__main__':
         if sweep % 50 == 0:
             print('sweep:', sweep, ', x residual:', xres, \
                                    ', y residual',  yres, \
                                    ', p residual:', pres, \
                                    ', continuity:', max(abs(rhs)))
             plt.figure(num=1, figsize=(10,10))
     
             viewer.plot()

     # Criteria to stop
     if (max(xres, yres) < eps):
        print("Residuals are less than: {0}".format(eps))
        break        
     else:
        continue
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 22
#      18 xres = xVelocityEq.sweep(var=xVelocity,
#      19                          underRelaxation=velocityRelaxation)
#      20 xmat = xVelocityEq.matrix
# ---> 22 yres = yVelocityEq.sweep(var=yVelocity,
#      23                          underRelaxation=velocityRelaxation)
#      24 ############################################################################
#      25
#      26
#      27 ## update the ap coefficient from the matrix diagonal
#      28 ap[:] = -numerix.asarray(xmat.takeDiagonal())
#
# File E:\15_REPOS\d01_fipy\fipy\terms\term.py:243, in Term.sweep(self, var, solver, boundaryConditions, dt, underRelaxation, residualFn, cacheResidual, cacheError)
#     240 self._log.debug("BEGIN sweep")
#     242 with Timer() as t:
# --> 243     solver = self._prepareLinearSystem(var=var, solver=solver, boundaryConditions=boundaryConditions, dt=dt)
#     244     solver._applyUnderRelaxation(underRelaxation=underRelaxation)
#     245     residual = solver._calcResidual(residualFn=residualFn)
#
# File E:\15_REPOS\d01_fipy\fipy\terms\term.py:138, in Term._prepareLinearSystem(self, var, solver, boundaryConditions, dt)
#     133         from fipy.viewers.matplotlibViewer.matplotlibSparseMatrixViewer import MatplotlibSparseMatrixViewer
#     134         Term._viewer = MatplotlibSparseMatrixViewer()
#     136 (var,
#     137  matrix,
# --> 138  RHSvector) = self._buildAndAddMatrices(var,
#     139                                         self._getMatrixClass(solver, var),
#     140                                         boundaryConditions=boundaryConditions,
#     141                                         dt=dt,
#     142                                         transientGeomCoeff=self._getTransientGeomCoeff(var),
#     143                                         diffusionGeomCoeff=self._getDiffusionGeomCoeff(var),
#     144                                         buildExplicitIfOther=self._buildExplcitIfOther)
#     146 self._buildCache(matrix, RHSvector)
#     148 solver._storeMatrix(var=var, matrix=matrix, RHSvector=RHSvector)
#
# File E:\15_REPOS\d01_fipy\fipy\terms\binaryTerm.py:27, in _BinaryTerm._buildAndAddMatrices(self, var, SparseMatrix, boundaryConditions, dt, transientGeomCoeff, diffusionGeomCoeff, buildExplicitIfOther)
#      23 RHSvector = 0
#      25 for term in (self.term, self.other):
# ---> 27     tmpVar, tmpMatrix, tmpRHSvector = term._buildAndAddMatrices(var,
#      28                                                                 SparseMatrix,
#      29                                                                 boundaryConditions=boundaryConditions,
#      30                                                                 dt=dt,
#      31                                                                 transientGeomCoeff=transientGeomCoeff,
#      32                                                                 diffusionGeomCoeff=diffusionGeomCoeff,
#      33                                                                 buildExplicitIfOther=buildExplicitIfOther)
#      35     matrix += tmpMatrix
#      36     RHSvector += tmpRHSvector
#
# File E:\15_REPOS\d01_fipy\fipy\terms\binaryTerm.py:27, in _BinaryTerm._buildAndAddMatrices(self, var, SparseMatrix, boundaryConditions, dt, transientGeomCoeff, diffusionGeomCoeff, buildExplicitIfOther)
#      23 RHSvector = 0
#      25 for term in (self.term, self.other):
# ---> 27     tmpVar, tmpMatrix, tmpRHSvector = term._buildAndAddMatrices(var,
#      28                                                                 SparseMatrix,
#      29                                                                 boundaryConditions=boundaryConditions,
#      30                                                                 dt=dt,
#      31                                                                 transientGeomCoeff=transientGeomCoeff,
#      32                                                                 diffusionGeomCoeff=diffusionGeomCoeff,
#      33                                                                 buildExplicitIfOther=buildExplicitIfOther)
#      35     matrix += tmpMatrix
#      36     RHSvector += tmpRHSvector
#
# File E:\15_REPOS\d01_fipy\fipy\terms\unaryTerm.py:67, in _UnaryTerm._buildAndAddMatrices(self, var, SparseMatrix, boundaryConditions, dt, transientGeomCoeff, diffusionGeomCoeff, buildExplicitIfOther)
#      60     var, matrix, RHSvector = self._buildMatrix(var,
#      61                                                SparseMatrix,
#      62                                                boundaryConditions=boundaryConditions,
#      63                                                dt=dt,
#      64                                                transientGeomCoeff=transientGeomCoeff,
#      65                                                diffusionGeomCoeff=diffusionGeomCoeff)
#      66 elif buildExplicitIfOther:
# ---> 67     _, matrix, RHSvector = self._buildMatrix(self.var,
#      68                                              SparseMatrix,
#      69                                              boundaryConditions=boundaryConditions,
#      70                                              dt=dt,
#      71                                              transientGeomCoeff=transientGeomCoeff,
#      72                                              diffusionGeomCoeff=diffusionGeomCoeff)
#      73     RHSvector = RHSvector - matrix * self.var.value
#      74     matrix = SparseMatrix(mesh=var.mesh)
#
# File E:\15_REPOS\d01_fipy\fipy\terms\abstractDiffusionTerm.py:458, in _AbstractDiffusionTerm._buildMatrix(self, var, SparseMatrix, boundaryConditions, dt, transientGeomCoeff, diffusionGeomCoeff)
#     455 else:
#     456     raise ValueError("Order of diffusion coefficient must be non-zero and even, not {}".format(self.order))
# --> 458 return buildFn(var=var,
#     459                SparseMatrix=SparseMatrix,
#     460                boundaryConditions=boundaryConditions,
#     461                dt=dt,
#     462                transientGeomCoeff=transientGeomCoeff,
#     463                diffusionGeomCoeff=diffusionGeomCoeff)
#
# File E:\15_REPOS\d01_fipy\fipy\terms\abstractDiffusionTerm.py:689, in _AbstractDiffusionTerm._secondOrderBuildMatrix(self, var, SparseMatrix, boundaryConditions, dt, transientGeomCoeff, diffusionGeomCoeff)
#     684 ids = self._reshapeIDs(var, numerix.arange(mesh.numberOfCells,
#     685                                            dtype=INDEX_TYPE))
#     686 L.addAt(self.constraintL[var].ravel(),
#     687         ids.ravel(),
#     688         ids.swapaxes(0, 1).ravel())
# --> 689 b += numerix.reshape(self.constraintB[var].ravel(),
#     690                      ids.shape).sum(-2).ravel()
#     692 return (var, L, b)
#
# File E:\15_REPOS\d01_fipy\fipy\variables\variable.py:1389, in Variable.ravel(self)
#    1388 def ravel(self):
# -> 1389     return self.value.ravel()
#
# File E:\15_REPOS\d01_fipy\fipy\variables\variable.py:481, in Variable._getValue(self)
#     466 """
#     467 "Evaluate" the `Variable` and return its value (longhand)
#     468
#    (...)    477
#     478 """
#     480 if self.stale or not self._isCached() or self._value is None:
# --> 481     value = self._calcValue()
#     482     if self._isCached():
#     483         self._setValueInternal(value=value)
#
# File E:\15_REPOS\d01_fipy\fipy\variables\operatorVariable.py:52, in _OperatorVariableClass.<locals>._OperatorVariable._calcValue(self)
#      50     return self._execInline(comment=self.comment)
#      51 else:
# ---> 52     return self._calcValue_()
#
# File E:\15_REPOS\d01_fipy\fipy\variables\binaryOperatorVariable.py:47, in _BinaryOperatorVariable.<locals>.binOp._calcValue_(self)
#      44         self.var[1] = physicalField.PhysicalField(value=self.var[1])
#      45     val1 = self.var[1]
# ---> 47 value = self.op(self.var[0].value, val1)
#      48 if self.return_scalar:
#      49     value = value[()]
#
# File E:\15_REPOS\d01_fipy\fipy\variables\variable.py:481, in Variable._getValue(self)
#     466 """
#     467 "Evaluate" the `Variable` and return its value (longhand)
#     468
#    (...)    477
#     478 """
#     480 if self.stale or not self._isCached() or self._value is None:
# --> 481     value = self._calcValue()
#     482     if self._isCached():
#     483         self._setValueInternal(value=value)
#
# File E:\15_REPOS\d01_fipy\fipy\variables\operatorVariable.py:52, in _OperatorVariableClass.<locals>._OperatorVariable._calcValue(self)
#      50     return self._execInline(comment=self.comment)
#      51 else:
# ---> 52     return self._calcValue_()
#
# File E:\15_REPOS\d01_fipy\fipy\variables\binaryOperatorVariable.py:47, in _BinaryOperatorVariable.<locals>.binOp._calcValue_(self)
#      44         self.var[1] = physicalField.PhysicalField(value=self.var[1])
#      45     val1 = self.var[1]
# ---> 47 value = self.op(self.var[0].value, val1)
#      48 if self.return_scalar:
#      49     value = value[()]
#
# File E:\15_REPOS\d01_fipy\fipy\variables\variable.py:481, in Variable._getValue(self)
#     466 """
#     467 "Evaluate" the `Variable` and return its value (longhand)
#     468
#    (...)    477
#     478 """
#     480 if self.stale or not self._isCached() or self._value is None:
# --> 481     value = self._calcValue()
#     482     if self._isCached():
#     483         self._setValueInternal(value=value)
#
# File E:\15_REPOS\d01_fipy\fipy\variables\operatorVariable.py:52, in _OperatorVariableClass.<locals>._OperatorVariable._calcValue(self)
#      50     return self._execInline(comment=self.comment)
#      51 else:
# ---> 52     return self._calcValue_()
#
# File E:\15_REPOS\d01_fipy\fipy\variables\unaryOperatorVariable.py:35, in _UnaryOperatorVariable.<locals>.unOp._calcValue_(self)
#      34 def _calcValue_(self):
# ---> 35     value = self.op(self.var[0].value)
#      36     if self.return_scalar:
#      37         value = value[()]
#
# File E:\15_REPOS\d01_fipy\fipy\variables\variable.py:481, in Variable._getValue(self)
#     466 """
#     467 "Evaluate" the `Variable` and return its value (longhand)
#     468
#    (...)    477
#     478 """
#     480 if self.stale or not self._isCached() or self._value is None:
# --> 481     value = self._calcValue()
#     482     if self._isCached():
#     483         self._setValueInternal(value=value)
#
# File E:\15_REPOS\d01_fipy\fipy\variables\addOverFacesVariable.py:29, in _AddOverFacesVariable._calcValue(self)
#      27     return self._calcValueInline()
#      28 else:
# ---> 29     return self._calcValueNoInline()
#
# File E:\15_REPOS\d01_fipy\fipy\variables\addOverFacesVariable.py:70, in _AddOverFacesVariable._calcValueNoInline(self)
#      67 def _calcValueNoInline(self):
#      68     ids = self.mesh.cellFaceIDs
# ---> 70     contributions = numerix.take(self.faceVariable, ids, axis=-1)
#      72     # FIXME: numerix.MA.filled casts away dimensions
#      73     s = (numerix.newaxis,) * (len(contributions.shape) - 2) + (slice(0, None, None),) + (slice(0, None, None),)
#
# File E:\15_REPOS\d01_fipy\fipy\tools\numerix.py:600, in take(a, indices, axis, fill_value)
#     595 """
#     596 Selects the elements of `a` corresponding to `indices`.
#     597 """
#     599 if _isPhysical(a):
# --> 600     taken = a.take(indices, axis=axis)
#     601 elif isinstance(indices, type(MA.array((0)))):
#     602     ## Replaces `MA.take`. `MA.take` does not always work when
#     603     ## `indices` is a masked array.
#     604     ##
#     605     taken = MA.take(a, MA.filled(indices, 0), axis=axis)
#
# File E:\15_REPOS\d01_fipy\fipy\variables\variable.py:1461, in Variable.take(self, ids, axis)
#    1460 def take(self, ids, axis=0):
# -> 1461     return numerix.take(self.value, ids, axis)
#
# File E:\15_REPOS\d01_fipy\fipy\variables\variable.py:481, in Variable._getValue(self)
#     466 """
#     467 "Evaluate" the `Variable` and return its value (longhand)
#     468
#    (...)    477
#     478 """
#     480 if self.stale or not self._isCached() or self._value is None:
# --> 481     value = self._calcValue()
#     482     if self._isCached():
#     483         self._setValueInternal(value=value)
#
# File E:\15_REPOS\d01_fipy\fipy\variables\operatorVariable.py:46, in _OperatorVariableClass.<locals>._OperatorVariable._calcValue(self)
#      44 def _calcValue(self):
#      45     if not self.canInline:
# ---> 46         return self._calcValue_()
#      47     else:
#      48         from fipy.tools import inline
#
# File E:\15_REPOS\d01_fipy\fipy\variables\unaryOperatorVariable.py:35, in _UnaryOperatorVariable.<locals>.unOp._calcValue_(self)
#      34 def _calcValue_(self):
# ---> 35     value = self.op(self.var[0].value)
#      36     if self.return_scalar:
#      37         value = value[()]
#
# File E:\15_REPOS\d01_fipy\fipy\variables\variable.py:1414, in Variable.sum.<locals>.<lambda>(a)
#    1412 def sum(self, axis=None):
#    1413     return self._axisOperator(opname="sumVar",
# -> 1414                               op=lambda a: numerix.sum(a, axis=axis),
#    1415                               axis=axis)
#
# File E:\15_REPOS\d01_fipy\fipy\tools\numerix.py:268, in sum(arr, axis)
#     266 if axis is None:
#     267     axis = 0
# --> 268 return NUMERIX.tensordot(NUMERIX.ones(arr.shape[axis], 'l'), arr, (0, axis))
#
# File ~\AppData\Roaming\Python\Python313\site-packages\numpy\_core\numeric.py:1211, in tensordot(a, b, axes)
#    1209 at = a.transpose(newaxes_a).reshape(newshape_a)
#    1210 bt = b.transpose(newaxes_b).reshape(newshape_b)
# -> 1211 res = dot(at, bt)
#    1212 return res.reshape(olda + oldb)
#
# KeyboardInterrupt:
